# %% [markdown]
# # Lung_Cancer_Survey_Analysis_and_Detection_(Random Forest Model)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/content/survey lung cancer.csv')

# %%
data.head()
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   69        1               2        2              1
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# ...

# %%
data.isnull().sum()
# Out:
# GENDER                   0
# AGE                      0
# SMOKING                  0
# YELLOW_FINGERS           0
# ANXIETY                  0
# PEER_PRESSURE            0
# CHRONIC DISEASE          0
# FATIGUE                  0
# ALLERGY                  0
# WHEEZING                 0
# ALCOHOL CONSUMING        0
# COUGHING                 0
# SHORTNESS OF BREATH      0
# SWALLOWING DIFFICULTY    0
# CHEST PAIN               0
# LUNG_CANCER              0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['Gender_encoded'] = le.fit_transform(data['GENDER'])
data
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
sns.boxplot(data['AGE'])
plt.show()

# %%
from scipy.stats import zscore
z_scores = zscore(data['AGE'])
data[np.abs(z_scores)>3]
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 22       F   21        2               1        1              1
# 238      F   38        1               2        1              1
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 22                 2         2         2         1                  1
# 238                2         2         2         2                  1
#
#      COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  \
# 22          1                    2                      1           1
# 238         2                    2                      1           2
#
#     LUNG_CANCER  Gender_encoded
# 22           NO               0
# 238         YES               0

# %%
#data['AGE'] = np.where(data['AGE'] < 40, data['AGE'].median(),data['AGE'])
#data
# Out:
#     GENDER   AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M  69.0        1               2        2              1
# 1        M  74.0        2               1        1              1
# 2        F  59.0        1               1        1              2
# 3        M  63.0        2               2        2              1
# 4        F  63.0        1               2        1              1
# ..     ...   ...      ...             ...      ...            ...
# 304      F  56.0        1               1        1              2
# 305      M  70.0        2               1        1              1
# 306      M  58.0        2               1        1              1
# 307      M  67.0        2               1        2              1
# 308      M  62.0        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['LUNG_CANCER'] = le.fit_transform(data['LUNG_CANCER'])
data['GENDER'] = le.fit_transform(data['GENDER'])
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         1   69        1               2        2              1
# 1         1   74        2               1        1              1
# 2         0   59        1               1        1              2
# 3         1   63        2               2        2              1
# 4         0   63        1               2        1              1
# ..      ...  ...      ...             ...      ...            ...
# 304       0   56        1               1        1              2
# 305       1   70        2               1        1              1
# 306       1   58        2               1        1              1
# 307       1   67        2               1        2              1
# 308       1   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
x = data.drop('LUNG_CANCER',axis = 1)
y = data['LUNG_CANCER']

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2)

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(random_state=40, n_jobs=-1, max_depth=5, n_estimators=1000, oob_score=False)

# %%
clf.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier(max_depth=5, n_estimators=1000, n_jobs=-1,
#                        random_state=40)

# %%
ypred = clf.predict(xtest)
from sklearn.metrics import accuracy_score
accuracy_score(ytest,ypred)
# Out:
# 0.9354838709677419
